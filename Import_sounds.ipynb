# %%
import requests
import os
import urllib.parse

# %%
# Define the API base URL
api_base_url = "https://xeno-canto.org/api/2/recordings"

# List of bird genera
bird_genera = ["Carpodacus", "Luscinia", "Podiceps", "Bucephala", "Acanthis", "Glaucidium", "Pluvialis", "Hydroprogne", "Sylvia", "Calcarius", "Panurus", "Uria", "Perdix", "Eptesicus", "Ardea", "Spatula", "Pica", "Prunella", "Parus", "Oriolus", "Calandrella", "Stercorarius", "Rallus", "Sternula", "Branta", "Actitis", "Sitta", "Barbastella", "Picoides", "Chroicocephalus", "Surnia", "Iduna", "Anser", "Nucifraga", "Mergellus", "Lymnocryptes", "Sonus", "Dendrocopos", "Riparia", "Jynx", "Numenius", "Pinicola", "Garrulus", "Cecropis", "Porzana", "Picus", "Nycticorax", "Limosa", "Calidris", "Lanius", "Phylloscopus", "Oenanthe", "Lullula", "Nyctalus", "Lyrurus", "Phalacrocorax", "Fringilla", "Troglodytes", "Milvus", "Hirundo", "Aythya", "Locustella", "Ficedula", "Plecotus", "Alcedo", "Dryobates", "Aegithalos", "Poecile", "Cepphus", "Remiz", "Metrioptera", "Columba", "Meconema", "Ciconia", "Bucanetes", "Aix", "Fulica", "Recurvirostra", "Perisoreus", "Delichon", "Ichthyaetus", "Linaria", "Alauda", "Scolopax", "Chlidonias", "Alca", "Vespertilio", "Tetrastes", "Hydrocoloeus", "Coturnix", "Periparus", "Pernis", "Phoenicurus", "Charadrius", "Crex", "Aquila", "Certhia", "Motacilla", "Grus", "Mystery", "Phalaropus", "Coloeus", "Erithacus", "Thalasseus", "Arenaria", "Pipistrellus", "Vanellus", "Gryllus", "Plectrophenax", "Myotis", "Dryocopus", "Passer", "Muscicapa", "Zapornia", "Strix", "Eremophila", "Xenus", "Gallinago", "Clangula", "Serinus", "Caprimulgus", "Streptopelia", "Otus", "Chloris", "Asio", "Mergus", "Psophus", "Lagopus", "Larus", "Gavia"]


# Maximum number of files to download for each genus
max_files_per_genus = 500

# Create the main directory if it doesn't exist
main_directory = "Bird_Recordings"
os.makedirs(main_directory, exist_ok=True)

# %%
# Iterate through each bird genus
for bird_genus in bird_genera:
    # Define the query parameters for the current genus
    query_params = {
        "query": f"gen:{bird_genus}",
    }

    # Make the API request for the current genus
    response = requests.get(f"{api_base_url}?{urllib.parse.urlencode(query_params)}")

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        data = response.json()

        # Check the number of sounds for the current genus
        num_sounds = len(data['recordings'])

        # Proceed only if the genus has 200 or more sounds
        if num_sounds >= 200:
            # Create a folder for each bird genus within the main directory
            genus_folder = os.path.join(main_directory, bird_genus)
            os.makedirs(genus_folder, exist_ok=True)

            # Counter for the number of files downloaded for the current genus
            files_downloaded = 0

            # Process the data for the current genus
            for recording in data['recordings']:
                # Check if the recording has an audio file URL in the "file" field
                if 'file' in recording and recording['file']:
                    audio_url = recording['file']
                    filename = os.path.join(genus_folder, f"{recording['gen']}_{recording['id']}.mp3")

                    try:
                        # Download and save the audio file
                        audio_data = requests.get(audio_url).content
                        with open(filename, 'wb') as audio_file:
                            audio_file.write(audio_data)

                        # Increment the counter
                        files_downloaded += 1

                        # Break out of the loop if the maximum number of files is reached
                        if files_downloaded >= max_files_per_genus:
                            break
                    except Exception as e:
                        print(f"Error downloading {audio_url}: {e}")

            print(f"{files_downloaded} audio files for {bird_genus} downloaded and organized.")
        else:
            print(f"Skipping {bird_genus} because it has less than 200 sounds.")
    else:
        print(f"API request for {bird_genus} failed with status code {response.status_code}")
# Out:
# 500 audio files for Carpodacus downloaded and organized.
# 500 audio files for Luscinia downloaded and organized.
# 500 audio files for Podiceps downloaded and organized.
# 310 audio files for Bucephala downloaded and organized.
# 500 audio files for Acanthis downloaded and organized.
# 500 audio files for Glaucidium downloaded and organized.
# 500 audio files for Pluvialis downloaded and organized.
# 365 audio files for Hydroprogne downloaded and organized.
# 500 audio files for Sylvia downloaded and organized.
# 500 audio files for Calcarius downloaded and organized.
# 365 audio files for Panurus downloaded and organized.
# Skipping Uria because it has less than 200 sounds.
# 336 audio files for Perdix downloaded and organized.
# Skipping Eptesicus because it has less than 200 sounds.
# 500 audio files for Ardea downloaded and organized.
# 500 audio files for Spatula downloaded and organized.
# 500 audio files for Pica downloaded and organized.
# 500 audio files for Prunella downloaded and organized.
# 500 audio files for Parus downloaded and organized.
# 473 audio files for Oriolus downloaded and organized.
# 380 audio files for Calandrella downloaded and organized.
# 249 audio files for Stercorarius downloaded and organized.
# 500 audio files for Rallus downloaded and organized.
# 500 audio files for Sternula downloaded and organized.
# 500 audio files for Branta downloaded and organized.
# 500 audio files for Actitis downloaded and organized.
# 500 audio files for Sitta downloaded and organized.
# Skipping Barbastella because it has less than 200 sounds.
# 500 audio files for Picoides downloaded and organized.
# 500 audio files for Chroicocephalus downloaded and organized.
# Skipping Surnia because it has less than 200 sounds.
# 500 audio files for Iduna downloaded and organized.
# 500 audio files for Anser downloaded and organized.
# 500 audio files for Nucifraga downloaded and organized.
# Skipping Mergellus because it has less than 200 sounds.
# Skipping Lymnocryptes because it has less than 200 sounds.
# 500 audio files for Sonus downloaded and organized.
# 500 audio files for Dendrocopos downloaded and organized.
# 392 audio files for Riparia downloaded and organized.
# 500 audio files for Jynx downloaded and organized.
# 500 audio files for Numenius downloaded and organized.
# 268 audio files for Pinicola downloaded and organized.
# 500 audio files for Garrulus downloaded and organized.
# 458 audio files for Cecropis downloaded and organized.
# 500 audio files for Porzana downloaded and organized.
# 500 audio files for Picus downloaded and organized.
# 500 audio files for Nycticorax downloaded and organized.
# 500 audio files for Limosa downloaded and organized.
# 500 audio files for Calidris downloaded and organized.
# 500 audio files for Lanius downloaded and organized.
# 500 audio files for Phylloscopus downloaded and organized.
# 500 audio files for Oenanthe downloaded and organized.
# 500 audio files for Lullula downloaded and organized.
# Skipping Nyctalus because it has less than 200 sounds.
# 265 audio files for Lyrurus downloaded and organized.
# 263 audio files for Phalacrocorax downloaded and organized.
# 500 audio files for Fringilla downloaded and organized.
# 500 audio files for Troglodytes downloaded and organized.
# 440 audio files for Milvus downloaded and organized.
# 500 audio files for Hirundo downloaded and organized.
# 474 audio files for Aythya downloaded and organized.
# 500 audio files for Locustella downloaded and organized.
# 500 audio files for Ficedula downloaded and organized.
# Skipping Plecotus because it has less than 200 sounds.
# 500 audio files for Alcedo downloaded and organized.
# 500 audio files for Dryobates downloaded and organized.
# 500 audio files for Aegithalos downloaded and organized.
# 500 audio files for Poecile downloaded and organized.
# Skipping Cepphus because it has less than 200 sounds.
# 453 audio files for Remiz downloaded and organized.
# Skipping Metrioptera because it has less than 200 sounds.
# 500 audio files for Columba downloaded and organized.
# Skipping Meconema because it has less than 200 sounds.
# Skipping Ciconia because it has less than 200 sounds.
# 222 audio files for Bucanetes downloaded and organized.
# 216 audio files for Aix downloaded and organized.
# 500 audio files for Fulica downloaded and organized.
# 500 audio files for Recurvirostra downloaded and organized.
# 347 audio files for Perisoreus downloaded and organized.
# 500 audio files for Delichon downloaded and organized.
# 401 audio files for Ichthyaetus downloaded and organized.
# 500 audio files for Linaria downloaded and organized.
# 500 audio files for Alauda downloaded and organized.
# 500 audio files for Scolopax downloaded and organized.
# 500 audio files for Chlidonias downloaded and organized.
# Skipping Alca because it has less than 200 sounds.
# Skipping Vespertilio because it has less than 200 sounds.
# 344 audio files for Tetrastes downloaded and organized.
# Skipping Hydrocoloeus because it has less than 200 sounds.
# 500 audio files for Coturnix downloaded and organized.
# 500 audio files for Periparus downloaded and organized.
# 258 audio files for Pernis downloaded and organized.
# Error downloading https://xeno-canto.org/315660/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/315657/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/315655/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/315653/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/315651/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/315444/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/312436/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/310967/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/310946/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/310438/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/310132/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/310083/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/309015/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/309014/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/309013/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/308101/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/308094/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/308082/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/308070/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/308067/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/308064/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/308054/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/308048/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/308047/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/293590/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/281416/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/281415/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/281414/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/281413/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/281412/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/268757/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/255333/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/252641/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/247610/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/246187/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/246186/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/243758/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/237537/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/236963/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/199758/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/181914/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/171486/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/164504/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/164503/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/162606/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/158171/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/158170/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/156293/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/155195/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/148952/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/148950/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/148948/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/145237/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/144975/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/143380/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/143176/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/141410/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/141325/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/141179/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/138201/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/134040/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/133524/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/133485/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/133452/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/132603/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/131264/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/129621/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/129454/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/122440/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/111021/download: [Errno 122] Disk quota exceeded
# 430 audio files for Phoenicurus downloaded and organized.
# Error downloading https://xeno-canto.org/739121/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/100954/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/466596/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/390381/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/296049/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/182427/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/841006/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/837212/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/833681/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/833669/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/833667/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/833666/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/833658/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/832958/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/831972/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/831382/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/831134/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/830398/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/830079/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/829077/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/828553/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/828255/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/827820/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/826723/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/826479/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/826478/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/826455/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/826375/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/824990/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/814267/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/805206/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/802774/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/800433/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/799403/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/798482/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/797628/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/796533/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/795265/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/795089/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/794974/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/789591/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/781642/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/776262/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/771630/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/770133/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/770132/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/770131/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/770080/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/766551/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/763623/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/760459/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/759887/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/759886/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/759884/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/759882/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/757044/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/754947/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/754520/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/750866/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/750332/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/750331/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/750330/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/749468/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/749466/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/749325/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/748799/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/748313/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/748312/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/748310/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/748309/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/747719/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/746674/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/746008/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/744912/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/744536/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/744535/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/744534/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/744127/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/742299/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/741001/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/740387/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/740084/download: [Errno 122] Disk quota exceeded
# Error downloading https://xeno-canto.org/740083/download: [Errno 122] Disk quota exceeded
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 36
#      32 filename = os.path.join(genus_folder, f"{recording['gen']}_{recording['id']}.mp3")
#      34 try:
#      35     # Download and save the audio file
# ---> 36     audio_data = requests.get(audio_url).content
#      37     with open(filename, 'wb') as audio_file:
#      38         audio_file.write(audio_data)
#
# File /usr/local/lib/python3.11/dist-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /usr/local/lib/python3.11/dist-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /usr/local/lib/python3.11/dist-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /usr/local/lib/python3.11/dist-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File /usr/lib/python3.11/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File /usr/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/lib/python3.11/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /usr/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:
